# %%
# Resource Link
#https://seaborn.pydata.org/

# %%
import seaborn as sns
sns.__version__
import scipy.stats as stats
from scipy.stats import pearsonr

import matplotlib.style
import matplotlib as mpl
mpl.rcParams['patch.force_edgecolor'] = True
mpl.style.use('classic')

from warnings import filterwarnings
filterwarnings('ignore')

# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Distribution Plots

# %%
sns.distplot(tips['total_bill'], kde= False, bins=30)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.jointplot(x='total_bill', y='tip', data=tips) # two distribution plots jointed together, in between it's a scatterplot

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex') # two distribution plots jointed together, in between it's a scatterplot

# %%
# Regression Plot
import scipy.stats as stats

sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg') # two distribution plots jointed together, in between it's a scatterplot

# %%
import scipy.stats as stats
sns.jointplot(x='total_bill', y='tip', data=tips, kind='kde', stat_func =stats.pearsonr)

# %%
# Pairplot
sns.pairplot(tips, hue='sex', palette = 'coolwarm')  #Pass on a categorical column name

# %%
# rugplot
sns.rugplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
# Comparison between rugplot and histogram(distplot): rugplot simply draws dashplot
sns.distplot(tips['total_bill'], kde=False)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
#  kde plot
# Don't worry about understanding this code!
# It's just for the diagram below
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

#Create dataset
dataset = np.random.randn(25)

# Create another rugplot
sns.rugplot(dataset);

# Set up the x-axis for the plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2

# 100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max,100)

# Set up the bandwidth, for info on this:
url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2


# Create an empty kernel list
kernel_list = []

# Plot each basis function
for data_point in dataset:
    
    # Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)

plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
# To get the kde plot 
sns.kdeplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
## Categorical Plots

# %%
import seaborn as sns
# %matplotlib inline
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='sex', y='total_bill', data=tips, estimator=np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#Boxplot
sns.boxplot(x='day', y='total_bill', data=tips, hue='smoker')
# Dots above the boxplots are outliers.
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='size')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='day')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='time')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
fig,ax = plt.subplots(1,2) # Using subplot function and create two plot
sns.set(rc={"figure.figsize":(20, 4)}) #width=8, height=4
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex', ax=ax[0])
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex', split=True, ax=ax[1])
fig.show()

# %%
#stripplot
sns.stripplot(x='day',y='total_bill', data=tips, jitter=False)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#stripplot
sns.stripplot(x='day',y='total_bill', data=tips, jitter=True, hue='sex', split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#swarmplot
sns.swarmplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
sns.swarmplot(x='day', y='total_bill', data=tips, color='black')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#factorplot
sns.factorplot(x='day', y='total_bill', data=tips, kind='bar')

# %%
# Matrix Plot
import seaborn as sns
# %matplotlib inline
tips= sns.load_dataset('tips')
flights = sns.load_dataset('flights')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tc = tips.corr()

# %%
sns.heatmap(tc, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
tc
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
fp = flights.pivot_table(index = 'month', columns='year', values='passengers')

# %%
sns.heatmap(fp, cmap='magma', linecolor='white', linewidths=1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(fp, cmap='magma', linecolor='white', linewidths=3)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(fp, cmap='coolwarm', linecolor='white', linewidths=3)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(fp, cmap='coolwarm', linecolor='black', linewidth=3)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
#clustermap
sns.clustermap(fp)
