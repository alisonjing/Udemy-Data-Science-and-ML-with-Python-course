# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('kyphosis.csv')

# %%
df.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
sns.pairplot(df, hue='Kyphosis')

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Kyphosis', axis= 1)

# %%
y = df['Kyphosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test, predictions))
print("\n")
print(classification_report(y_test, predictions))
# Out:
# [[18  1]
#  [ 2  4]]
#
#
#               precision    recall  f1-score   support
#
#       absent       0.90      0.95      0.92        19
#      present       0.80      0.67      0.73         6
#
#     accuracy                           0.88        25
#    macro avg       0.85      0.81      0.83        25
# weighted avg       0.88      0.88      0.88        25

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators = 200)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test, rfc_pred))
print("\n")
print(classification_report(y_test, rfc_pred))
# Out:
# [[19  0]
#  [ 4  2]]
#
#
#               precision    recall  f1-score   support
#
#       absent       0.83      1.00      0.90        19
#      present       1.00      0.33      0.50         6
#
#     accuracy                           0.84        25
#    macro avg       0.91      0.67      0.70        25
# weighted avg       0.87      0.84      0.81        25

# %%
df['Kyphosis'].value_counts()
# Out:
# absent     64
# present    17
# Name: Kyphosis, dtype: int64

# %%
# Add in Tree Graphs(installed graphviz in the terminal command)
# Import necessary packages for the trees

from IPython.display import Image
#from sklearn.externals.six import StringIO  (This command no longer works, see below stack overflow steps:
#https://stackoverflow.com/questions/61901365/modulenotfounderror-no-module-named-sklearn-externals-six)

import six
import sys
sys.modules['sklean.externals.six'] = six
from six import StringIO
from sklearn.tree import export_graphviz
import pydot

features = list(df.columns[1:])
features
# Out:
# ['Age', 'Number', 'Start']

# %%
dot_data = StringIO()
export_graphviz(dtree, out_file = dot_data, feature_names=features, filled=True, rounded=True)
graph = pydot.graph_from_dot_data(dot_data.getvalue())
Image(graph[0].create_png())
